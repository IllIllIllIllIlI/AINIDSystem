# %%
import numpy as np
import pandas as pd

# %%
dj = pd.read_csv('../data/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

# %%
print(dj[' Label'].value_counts())
# Out:
#  Label
# BENIGN              440031
# DoS Hulk            231073
# DoS GoldenEye        10293
# DoS slowloris         5796
# DoS Slowhttptest      5499
# Heartbleed              11
# Name: count, dtype: int64
